# %% [markdown]
# # ENTREGA FINAL
# **Nombre del alumno:** Mayra SOTO PEREZ
#
# **Datasets**: ventas.csv, clientes.csv, marketing.csv (en Drive).

# %% [markdown]
# ## ETAPA 1: Recopilación y Preparación de Datos

# %% [markdown]
# ###1- Crear un documento en Google Colaboratory y cargar los sets de datos como DataFrames.

# %%
from google.colab import drive
import pandas as pd
import numpy as np

# Montar Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Verificar que los archivos csv se encuentren en la carpeta datasets
import os
os.listdir("/content/drive/MyDrive/datasets")

ruta_ventas = "/content/drive/MyDrive/datasets/ventas.csv"
ruta_clientes = "/content/drive/MyDrive/datasets/clientes.csv"
ruta_marketing = "/content/drive/MyDrive/datasets/marketing.csv"

# Cargamos los CSV como DataFrames.
ventas = pd.read_csv(ruta_ventas)
clientes = pd.read_csv(ruta_clientes)
marketing = pd.read_csv(ruta_marketing)

# %% [markdown]
# ###2- Realizar un script básico que calcule las ventas mensuales utilizando variables y operadores.

# %%
# NO OBLIGATORIO

# %% [markdown]
# ###3- Estructuras de Datos: Desarrollar un programa que almacene los datos de ventas (producto, precio, cantidad). Decidir si conviene utilizar diccionarios o listas.

# %%
# NO OBLIGATORIO

# %% [markdown]
# ### 4- Introducción a Pandas: realizar un análisis exploratorio inicial de los DataFrames.

# %%
print("-----------------------------------")
print("########## CLIENTES RAW ###########")
print("-----------------------------------\n")
print("clientes.shape: ", clientes.shape,"\n")
display(clientes.head())
print("\n")
clientes.info()
print("\nNulos por columna:")
print(clientes.isna().sum())
print("\ndtypes:")
print(clientes.dtypes,"\n")

print("-----------------------------------")
print("########## MARKETING RAW ##########")
print("-----------------------------------\n")
print("marketing.shape: ", marketing.shape,"\n")
display(marketing.head())
print("\n")
marketing.info()
print("\nNulos por columna:")
print(marketing.isna().sum())
print("\ndtypes:")
print(marketing.dtypes,"\n")

print("-----------------------------------")
print("########## VENTAS RAW ############")
print("-----------------------------------\n")
print("ventas.shape: ", ventas.shape,"\n")
display(ventas.head())
print("\n")
ventas.info()
print("\nNulos por columna:")
print(ventas.isna().sum())
print("\ndtypes:")
print(ventas.dtypes,"\n")
# Out:
# -----------------------------------
# ########## CLIENTES RAW ###########
# -----------------------------------
#
# clientes.shape:  (567, 5)
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# ...

# %% [markdown]
# ### 5- Calidad de Datos: Identificar valores nulos y duplicados en los conjuntos de datos. Documentar el estado inicial de los datos.

# %%
def ident_nul_dup(df, nombredf, columna_clave=None):

  print("-----------------------------------")
  print("########## ", nombredf, " ############") #muestra el nombre
  print("-----------------------------------\n")
  print("Valores Nulos por columna:\n----------------------")
  print(df.isnull().sum()) #para contar valores nulos.

  print('\nCant. filas duplicadas:', df.duplicated(keep=False).sum()) #para contar filas duplicados (keep=False para marcar como True todas las filas que tienen otra igual)
  print("")

  if columna_clave and columna_clave in df.columns :    # ingresa solo si se pasa una columna y dicha columna está en dicho df.

        # Contar cuántas filas tienen valores repetidos en esa columna
        dup_key = df[columna_clave].duplicated(keep=False).sum()
        print(f"Duplicados por clave '{columna_clave}':", dup_key, "\n")

        # Si existen duplicados, mostrar cuáles son los valores más repetidos
        if dup_key > 0:
            duplicados_ordenados = (
                df[df[columna_clave].duplicated(keep=False)][columna_clave] #filtrar el df para que te devuelva solo los duplicados
                .value_counts()# Cuenta cuántas veces aparece cada valor
                .sort_values(ascending=False)   # Ordena de mayor a menor (más duplicados arriba)
            )

            print("\n🔁 Top 5 valores duplicados más frecuentes:")
            # Mostrar solo los primeros 5 (los más repetidos)
            display(duplicados_ordenados.head(5))
        else:
            print(f"No se encontraron duplicados en la clave '{columna_clave}'.\n")
  else:
        # Si la clave no fue pasada o no existe en el DataFrame
        if columna_clave:
            print(f"La clave '{columna_clave}' no existe en el DataFrame.\n")
        else:
            print("No se indicó una clave para analizar duplicados por columna.\n")

# %%
ident_nul_dup(clientes,"CLIENTES RAW","id_cliente")
ident_nul_dup(ventas,"VENTAS RAW", "id_venta")
ident_nul_dup(marketing,"MARKETING RAW", "id_campanha")
# Out:
# -----------------------------------
# ##########  CLIENTES RAW  ############
# -----------------------------------
#
# Valores Nulos por columna:
# ----------------------
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
#
# Cant. filas duplicadas: 0
#
# Duplicados por clave 'id_cliente': 0
#
# No se encontraron duplicados en la clave 'id_cliente'.
#
# -----------------------------------
# ##########  VENTAS RAW  ############
# -----------------------------------
#
# Valores Nulos por columna:
# ----------------------
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# Cant. filas duplicadas: 70
#
# Duplicados por clave 'id_venta': 70
#
#
# 🔁 Top 5 valores duplicados más frecuentes:
# id_venta
# 56      2
# 421     2
# 424     2
# 1868    2
# 2545    2
# Name: count, dtype: int64
# -----------------------------------
# ...

# %% [markdown]
# ## ETAPA 2: Preprocesamiento y Limpieza de Datos

# %% [markdown]
# ### 1- Limpieza de Datos: Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados. Documentar el proceso y los resultados.

# %%
# Crear copias independientes para no modificar los originales

ventas_clean = ventas.copy()
clientes_clean = clientes.copy()
marketing_clean = marketing.copy()

# %%
# Eliminar filas completamente duplicadas

clientes_clean = clientes_clean.drop_duplicates()
ventas_clean = ventas_clean.drop_duplicates()
marketing_clean = marketing_clean.drop_duplicates()

# Chequear el estado
ident_nul_dup(clientes_clean,"CLIENTES","id_cliente")
ident_nul_dup(ventas_clean,"VENTAS", "id_venta")
ident_nul_dup(marketing_clean,"MARKETING", "id_campanha")
# Out:
# -----------------------------------
# ##########  CLIENTES  ############
# -----------------------------------
#
# Valores Nulos por columna:
# ----------------------
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
#
# Cant. filas duplicadas: 0
#
# Duplicados por clave 'id_cliente': 0
#
# No se encontraron duplicados en la clave 'id_cliente'.
#
# -----------------------------------
# ##########  VENTAS  ############
# -----------------------------------
#
# Valores Nulos por columna:
# ----------------------
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# Cant. filas duplicadas: 0
#
# Duplicados por clave 'id_venta': 0
#
# No se encontraron duplicados en la clave 'id_venta'.
#
# -----------------------------------
# ##########  MARKETING  ############
# -----------------------------------
#
# Valores Nulos por columna:
# ----------------------
# ...

# %%
# Función para limpiar texto en columnas tipo string

def normalizar_texto(df):

    for col in df.select_dtypes(include="object").columns:
        # Se agrupan las operaciones entre paréntesis () para escribirlas en varias líneas
        # Python evalúa todo el bloque como una única expresión.
        df[col] = (
            df[col]
            .astype(str) # .astype(str)  → convierte todo a texto
            .str.strip() # .str.strip()  → Elimina espacios al inicio y final
            .str.replace(r"[\u200b\t\r\n]", "", regex=True)
            # .str.replace(patron, reemplazo, regex=True)
            #   patron: expresión regular que busca caracteres invisibles (\u200b, tabulaciones, saltos)
            #   reemplazo: ""  → los elimina
            #   regex=True indica que 'patron' es una expresión regular.
            .str.replace(" +", " ", regex=True)
            # reemplaza "uno o más espacios consecutivos" por un solo espacio
            .str.title() # Convierte a Título: "juan pérez" → "Juan Pérez"
        )
        return df

clientes_clean = normalizar_texto(clientes_clean)
ventas_clean = normalizar_texto(ventas_clean)
marketing_clean = normalizar_texto(marketing_clean)

# %%
# Función para Normalizar fechas

# Si alguna columna contiene fechas (por ejemplo "fecha" o "fechanotificacion"), se intenta convertir a formato datetime de pandas.
# to_datetime intenta interpretar el formato y transforma valores inválidos en NaT (Not a Time).

def norm_fechas(df):
  contador = 0
  for col in df.columns:
    if "fecha" in col.lower():  # detecta columnas con la palabra "fecha"
            df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)
            # Parámetros:
            #   errors="coerce" → convierte valores no válidos en NaT (evita error)
            #   dayfirst=True   → interpreta formatos tipo "DD/MM/YYYY" (formato latino)
            print("Se normalizó la columna:",col)
            contador += 1
  if contador == 0: print("No se encontraron columnas de fecha para normalizar")
  print("------------------------")
  return df



clientes_clean = norm_fechas(clientes_clean)
ventas_clean = norm_fechas(ventas_clean)
marketing_clean = norm_fechas(marketing_clean)
# Out:
# No se encontraron columnas de fecha para normalizar
# ------------------------
# Se normalizó la columna: fecha_venta
# ------------------------
# Se normalizó la columna: fecha_inicio
# Se normalizó la columna: fecha_fin
# ------------------------

# %%
# Normalizar valores numéricos

# Campo "precio"

def norm_precio_pesos (df):
  for col in df.columns:
    if "precio" in col.lower():  # detecta columnas con la palabra "precio"
      df[col] = df[col].astype(str).str.replace("$", "", regex=False).str.replace(",", "", regex=False).str.strip()
              # .astype(str) Convierte todo a texto
              # .str.replace("$", "", regex=False) Elimina el símbolo $
              #  regex=False → interpreta "$" literalmente, no como expresión regular
              # .str.replace(",", "", regex=False) Elimina comas de miles 1,000  1000
              # .str.strip()  Quita espacios sobrantes

      df[col] = pd.to_numeric(df[col], errors="coerce")
      # pd.to_numeric convierte texto a número (float o int)
      # Parámetros: errors="coerce" → reemplaza valores no convertibles con NaN
  return df

#  Campo "cantidad"

def norm_cantidad(df):
  for col in df.columns:
    if "cantidad" in col.lower():
        df[col] = pd  .to_numeric(df[col], errors="coerce")  .astype("Int64")
        # .astype("Int64") usa el tipo entero de pandas que permite valores nulos (NaN)
  return df

clientes_clean = norm_cantidad(norm_precio_pesos(clientes_clean))
ventas_clean = norm_cantidad(norm_precio_pesos(ventas_clean))
marketing_clean = norm_cantidad(norm_precio_pesos(marketing_clean))

# %% [markdown]
# Limpieza de Nulos

# %%
# Eliminar filas con valores nulos

ventas_clean = ventas_clean.dropna()
#ya que los nulos son en ventas sin precio ni cantidad, no me aportan nada, ni se podría reemplazar el valor

# %% [markdown]
# Guardar los DataFrames limpios como CSV

# %%
ventas_clean.to_csv("/content/drive/MyDrive/datasets/ventas_clean.csv", index=False)
clientes_clean.to_csv("/content/drive/MyDrive/datasets/clientes_clean.csv", index=False)
marketing_clean.to_csv("/content/drive/MyDrive/datasets/marketing_clean.csv", index=False)

print("✅ Archivos guardados: ventas_clean.csv, clientes_clean.csv, marketing_clean.csv")
# Out:
# ✅ Archivos guardados: ventas_clean.csv, clientes_clean.csv, marketing_clean.csv

# %% [markdown]
# Reporte Global luego de la limpieza de datos

# %%
# ============================================
# 📊 REPORTE GLOBAL DE CALIDAD DE DATOS
# ============================================
# Esta función lee los tres DataFrames limpios (o los recibe en memoria)
# y muestra un resumen comparativo de nulos, duplicados y tipos de datos.
# ============================================

def reporte_calidad_global(dfs, nombres):
    """
    Crea un resumen de calidad de varios DataFrames.

    Parámetros:
      dfs: lista de DataFrames (por ejemplo [ventas_clean, clientes_clean, marketing_clean])
      nombres: lista de nombres correspondientes (["VENTAS", "CLIENTES", "MARKETING"])
    """
    resumen = []
    #zip-->es una función incorporada de Python que une elementos de dos (o más) iterables
    # —por ejemplo, listas, tuplas o cualquier objeto iterable— en pares ordenados.
    for df, nombre in zip(dfs, nombres):
        nulos = df.isna().sum().sum()                    # Total de valores nulos, no por columnas sino total, por eso el doble sum
        duplicados = df.duplicated(keep='last').sum()    # Total de filas duplicadas | 'last' -> ya que quiero que coincidan los duplicados por las filas eliminadas por duplicados
        columnas = len(df.columns)                       # Cantidad de columnas
        filas = len(df)                                  # Cantidad de registros

        resumen.append({
            "Dataset": nombre,
            "Filas": filas,
            "Columnas": columnas,
            "Nulos totales": nulos,
            "Duplicados": duplicados,
        })

    reporte = pd.DataFrame(resumen)
    #display(reporte)
    return reporte


# ============================================

print(reporte_calidad_global([ventas, clientes, marketing], ["Ventas Raw", "Clientes Raw", "Marketing Raw"]))

print(reporte_calidad_global([ventas_clean, clientes_clean, marketing_clean], ["Ventas Clean", "Clientes Clean", "Marketing Clean"]))
# Out:
#          Dataset  Filas  Columnas  Nulos totales  Duplicados
# 0     Ventas Raw   3035         6              4          35
# 1   Clientes Raw    567         5              0           0
# 2  Marketing Raw     90         6              0           0
#            Dataset  Filas  Columnas  Nulos totales  Duplicados
# 0     Ventas Clean   2998         6              0           0
# 1   Clientes Clean    567         5              0           0
# 2  Marketing Clean     90         6              0           0

# %% [markdown]
# ###2- Transformación de Datos: Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.

# %%
# ============================================
# 7) TRANSFORMACIÓN: productos de alto rendimiento
# ============================================
# Objetivo:
# - Detectar los productos con mejor desempeño económico (top 20% por ingreso total).
# - Aplicar transformación: calcular ingreso, agregar por producto y filtrar.
# ============================================


# 1️⃣ Detectar la columna de producto

def encontrar_columna(df, candidatos):  #Busca la primera columna de un df cuyo nombre contenga alguno de los patrones (en minús) dados.
    for col in df.columns:
        nombre = col.lower()
        if any(p in nombre for p in candidatos):
            return col
    return None
# Nota didáctica:
# - Esto hace coincidencia por SUBCADENA (ej.: "prod" matchea "producto_sku").
# - Si querés coincidencia EXACTA, usá igualdad (c.lower() == p) o expresiones regulares.
# - Si tus datos pueden tener acentos/espacios raros, podés normalizar:
#     import unicodedata, re
#     def norm(s): return re.sub(r'\s+', ' ', ''.join(ch for ch in unicodedata.normalize('NFKD', s)
#                                    if not unicodedata.combining(ch))).strip().lower()


prod_col = encontrar_columna(ventas_clean, ["producto", "id_producto", "sku", "articulo", "artículo"])
if prod_col is None:
    raise ValueError("No se encontró columna de producto. Renombrá una columna a 'producto' o similar.")
print(prod_col)
# Out:
# producto

# %%
# 2️⃣ Calcular ingreso por registro = precio * cantidad

ventas_perf = (ventas_clean.assign(ingreso = ventas_clean["precio"] * ventas_clean["cantidad"]))
        # assign(**nuevas_col): crea nuevas columnas y devuelve una copia del DF.

ventas_perf.head()
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   69.94         5  2024-01-02
# 1       811    Lámpara De Mesa  105.10         5  2024-01-02
# 2      1156           Secadora   97.96         3  2024-01-02
# 3      1372           Heladera  114.35         8  2024-01-02
# 4      1546           Secadora  106.21         4  2024-01-02
#
#            categoria  ingreso
# 0         Decoración    349.7
# 1         Decoración    525.5
# 2  Electrodomésticos   293.88
# 3  Electrodomésticos    914.8
# 4  Electrodomésticos   424.84

# %%
# 3️⃣ Agregar métricas por producto
resumen_prod = (
    ventas_perf
    .groupby(
        by="producto",
        dropna=False,
        as_index=False,
        observed=False)
    .agg(
        ingreso_total=('ingreso', 'sum'),   # Suma de 'ingreso' por grupo (skipna=True por defecto).
        unidades=('cantidad', 'sum'),       # Suma de 'cantidad' por grupo.
        precio_promedio=('precio', 'mean'), # Promedio simple de 'precio' por grupo (ignora NaN).
        registros=('ingreso', 'size')       # Número de filas en el grupo (cuenta TODO, incluso NaN).
    )
)

resumen_prod.head()
# Out:
#           producto  ingreso_total  unidades  precio_promedio  registros
# 0  Adorno De Pared       48093.49       633        76.097800        100
# 1         Alfombra       44773.06       615        74.098300        100
# 2       Aspiradora       50085.86       651        77.447400        100
# 3      Auriculares       74175.58       958        76.302727        143
# 4         Batidora        50979.2       672        77.537200        100

# %%
#ordenar resumen_prod por el mayor ingreso_total, y redondear precio_promedio a 2 decimales redondeado
resumen_prod = resumen_prod.sort_values(by='ingreso_total', ascending=False)
resumen_prod['precio_promedio'] = resumen_prod['precio_promedio'].round(2)
display(resumen_prod.head(10))
# Out:
#              producto  ingreso_total  unidades  precio_promedio  registros
# 19    Lámpara De Mesa       82276.38      1112            72.72        176
# 3         Auriculares       74175.58       958            76.30        143
# 20         Microondas       72562.89       912            79.18        135
# 5            Cafetera       59607.31       765            79.05        117
# 9   Cuadro Decorativo        54297.6       726            74.58        100
# 26         Smartphone       54132.44       665            81.40        101
# 25           Secadora       52115.45       696            73.34        100
# 16  Jarrón Decorativo       51130.88       672            74.53        100
# 4            Batidora        50979.2       672            77.54        100
# 24  Rincón De Plantas       50456.45       691            74.82        101

# %%
# 4️⃣ Calcular percentil 80 de ingreso_total
# --------------------------------------------------------
# La función quantile() nos permite obtener el valor de un percentil.
# En este caso, queremos saber el ingreso que separa al 80% de los productos
# con menores ingresos del 20% con mayores ingresos.

p80_ingreso = resumen_prod["ingreso_total"].quantile(  q=0.80, interpolation="linear"  )


# 5️⃣ Filtrar los productos "de alto rendimiento" y ordenarlos
# -------------------------------------------------------------------
# Contexto: `resumen_prod` es un DataFrame con métricas por producto,
# y `p80_ingreso` es el percentil 80 de la columna "ingreso_total".
# Objetivo: quedarnos con los productos cuyo ingreso_total está en el 20% superior
# (ingreso_total >= p80_ingreso) y luego ordenarlos de mayor a menor por ingreso y unidades.
# en una sola fila

ventas_top = resumen_prod.query(
    "ingreso_total >= @p80_ingreso",engine="python"
).sort_values(
    by=["ingreso_total", "unidades"], ascending=[False, False], na_position="last", ignore_index=True
)



# 6️⃣ Mostrar resultados
print(f"Columna de producto detectada: {prod_col}")
print(f"Umbral (percentil 80) de ingreso_total: {float(p80_ingreso):,.2f}")
print("✅ Productos de ALTO RENDIMIENTO (top 20% por ingreso):")
display(ventas_top.head(20))
# Out:
# Columna de producto detectada: producto
# Umbral (percentil 80) de ingreso_total: 52,518.85
# ✅ Productos de ALTO RENDIMIENTO (top 20% por ingreso):
#             producto  ingreso_total  unidades  precio_promedio  registros
# 0    Lámpara De Mesa       82276.38      1112            72.72        176
# 1        Auriculares       74175.58       958            76.30        143
# 2         Microondas       72562.89       912            79.18        135
# 3           Cafetera       59607.31       765            79.05        117
# 4  Cuadro Decorativo        54297.6       726            74.58        100
# 5         Smartphone       54132.44       665            81.40        101

# %% [markdown]
# ###3- Agregación: Resumir las ventas por categoría de producto y analizar los ingresos generados.

# %%
# ============================================
# 8) AGREGACIÓN: resumen por categoría
# ============================================

# 1) Detectar columna de categoría (acepta variantes)
cat_col = encontrar_columna(ventas_clean, ["categoria", "categoría", "categoria_producto", "rubro"])
if cat_col is None:
    raise ValueError("No se encontró columna de categoría (por ej. 'categoria' o 'rubro').")

# 2) Asegurar columna 'ingreso' (si no existe, crearla)
if "ingreso" not in ventas_clean.columns:
    ventas_cat = ventas_clean.assign(ingreso = ventas_clean["precio"] * ventas_clean["cantidad"])
else:
    ventas_cat = ventas_clean.copy()

# 3) Agregación por categoría con groupby + agg
resumen_cat = (
    ventas_cat
    .groupby(
        by=cat_col,
        dropna=False,
        as_index=False
    )
    .agg(
        ingreso_total=('ingreso', 'sum'),
        unidades=('cantidad', 'sum'),
        ventas=('ingreso', 'size'),
        precio_promedio=('precio', 'mean')
    )
    .sort_values(
        by='ingreso_total',
        ascending=False,
        na_position='last',
        ignore_index=True
    )
)

# 4) Ticket promedio por venta = ingreso_total / ventas
resumen_cat = resumen_cat.assign(  # assign: crea/reescribe columnas
    ticket_promedio_por_venta = resumen_cat['ingreso_total'] / resumen_cat['ventas']

)

print("Columna de categoría detectada:", cat_col)
print("Resumen por categoría (ordenado por ingreso_total):")
display(resumen_cat.head(10))
# Out:
# Columna de categoría detectada: categoria
# Resumen por categoría (ordenado por ingreso_total):
#            categoria  ingreso_total  unidades  ventas  precio_promedio  \
# 0  Electrodomésticos      505299.63      6592    1000         76.52096
# 1        Electrónica       482577.8      6413     998         75.25492
# 2         Decoración      479216.09      6490    1000         74.09800
#
#    ticket_promedio_por_venta
# 0                  505.29963
# 1                  483.54489
# 2                  479.21609

# %% [markdown]
# ###4- Integración de Datos: Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.

# %%
#agrupo el df de ventas clean por producto y sum la cantidad por el precio
df_ventas_x_producto = ventas_clean.copy()
df_ventas_x_producto['precio_por_cantidad'] = df_ventas_x_producto['precio'] * df_ventas_x_producto['cantidad']

# Agrupar y agregar, asegurando que el índice sea una columna y las columnas no sean MultiIndex con reset_index
df_ventas_x_producto = df_ventas_x_producto.groupby('producto').agg(precio_por_cantidad=('precio_por_cantidad','sum')).reset_index()

# Ordeno por producto de forma ascendente
df_ventas_x_producto = df_ventas_x_producto.sort_values(by='producto', ascending=True)

# muestro resultado
display(df_ventas_x_producto.head(10))
print('Ahora las columnas deberían estar aplanadas:')
print(df_ventas_x_producto.columns)
# Out:
#                  producto  precio_por_cantidad
# 0         Adorno De Pared             48093.49
# 1                Alfombra             44773.06
# 2              Aspiradora             50085.86
# 3             Auriculares             74175.58
# 4                Batidora              50979.2
# 5                Cafetera             59607.31
# 6              Candelabro              11128.8
# 7  Consola De Videojuegos             46174.41
# 8                Cortinas             44865.03
# 9       Cuadro Decorativo              54297.6
# Ahora las columnas deberían estar aplanadas:
# Index(['producto', 'precio_por_cantidad'], dtype='object')

# %%
#agrupo marketing clean por producto y sumo el costo de las campañas de ese producto

df_marketing_x_producto = marketing_clean.groupby('producto')['costo'].sum().reset_index()
df_marketing_x_producto = df_marketing_x_producto[['producto', 'costo']] # Select only the desired columns
df_marketing_x_producto = df_marketing_x_producto.sort_values(by='producto', ascending=True) # Sort by product ascending
display(df_marketing_x_producto.head(10))
# Out:
#                  producto  costo
# 0         Adorno De Pared  14.05
# 1                Alfombra  17.46
# 2              Aspiradora  16.46
# 3             Auriculares  15.24
# 4                Batidora  15.28
# 5                Cafetera  18.16
# 6              Candelabro  14.65
# 7  Consola De Videojuegos  12.77
# 8                Cortinas  17.36
# 9       Cuadro Decorativo  15.85

# %%
#mergeo el df agrupado por producto con el de marketing agrupado por producto por producto

merged_df = pd.merge( df_ventas_x_producto, df_marketing_x_producto, on='producto' )
display(merged_df.head(10))
# Out:
#                  producto  precio_por_cantidad  costo
# 0         Adorno De Pared             48093.49  14.05
# 1                Alfombra             44773.06  17.46
# 2              Aspiradora             50085.86  16.46
# 3             Auriculares             74175.58  15.24
# 4                Batidora              50979.2  15.28
# 5                Cafetera             59607.31  18.16
# 6              Candelabro              11128.8  14.65
# 7  Consola De Videojuegos             46174.41  12.77
# 8                Cortinas             44865.03  17.36
# 9       Cuadro Decorativo              54297.6  15.85

# %%
#obtengo que % me representa el costo sobre el ingreso
merged_df['porcentaje_costo_sobre_ingreso'] = (merged_df['costo']/merged_df['precio_por_cantidad']*100).round(3)
display(merged_df)
# Out:
#                   producto  precio_por_cantidad  costo  \
# 0          Adorno De Pared             48093.49  14.05
# 1                 Alfombra             44773.06  17.46
# 2               Aspiradora             50085.86  16.46
# 3              Auriculares             74175.58  15.24
# 4                 Batidora              50979.2  15.28
# 5                 Cafetera             59607.31  18.16
# 6               Candelabro              11128.8  14.65
# 7   Consola De Videojuegos             46174.41  12.77
# 8                 Cortinas             44865.03  17.36
# 9        Cuadro Decorativo              54297.6  15.85
# 10          Cámara Digital             45217.96  16.40
# 11   Elementos De Cerámica             45411.09  16.87
# 12       Espejo Decorativo             46783.31  14.89
# 13      Freidora Eléctrica             50155.15  13.56
# 14                Heladera              25736.8  13.11
# 15         Horno Eléctrico              49913.9  13.89
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Diagrama de Caja (Box Plot) para 'porcentaje_costo_sobre_ingreso'
plt.figure(figsize=(10, 6))
sns.boxplot(x=merged_df['porcentaje_costo_sobre_ingreso'])
plt.title('Diagrama de Caja de Porcentaje de Costo sobre Ingreso')
plt.xlabel('Porcentaje de Costo sobre Ingreso')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograma para 'porcentaje_costo_sobre_ingreso'
plt.figure(figsize=(10, 6))
sns.histplot(merged_df['porcentaje_costo_sobre_ingreso'], bins=30, kde=True)
plt.title('Histograma de Porcentaje de Costo sobre Ingreso')
plt.xlabel('Porcentaje de Costo sobre Ingreso')
plt.ylabel('Frecuencia')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## ETAPA 3: Análisis de Datos

# %% [markdown]
# ### 1- Estadística Descriptiva: Calcular medidas de tendencia central y dispersión sobre las ventas. Presentar los resultados en un informe.

# %% [markdown]
# Ingresos totales por Producto

# %%
df = ventas_perf.groupby(by=prod_col).agg(
        ingreso_total=('ingreso', 'sum'),   # Suma de 'ingreso' por grupo (skipna=True por defecto).
        unidades=('cantidad', 'sum'),       # Suma de 'cantidad' por grupo.
        precio_promedio=('precio', 'mean'), # Promedio simple de 'precio' por grupo (ignora NaN).
        registros=('ingreso', 'size'),      # Número de filas en el grupo (cuenta TODO, incluso NaN).
        categoria=('categoria','first')
    ).reset_index()

df['precio_promedio'] = df['precio_promedio'].round(2)
display(df.head(5))
# Out:
#           producto  ingreso_total  unidades  precio_promedio  registros  \
# 0  Adorno De Pared       48093.49       633            76.10        100
# 1         Alfombra       44773.06       615            74.10        100
# 2       Aspiradora       50085.86       651            77.45        100
# 3      Auriculares       74175.58       958            76.30        143
# 4         Batidora        50979.2       672            77.54        100
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3        Electrónica
# 4  Electrodomésticos

# %%
# =========================================
# 📊 Gráfico de barras con etiquetas verticales dentro de cada barra
# =========================================

# Importamos la librería de gráficos matplotlib
import matplotlib.pyplot as plt

# Ordenamos el DataFrame por la columna "ingreso_total" de mayor a menor
# Esto permite que las barras se muestren ordenadas por el monto de ventas
df_ordenado = df.sort_values("ingreso_total", ascending=False)

# Creamos la figura donde se va a dibujar el gráfico
# figsize define el tamaño del gráfico (ancho, alto) en pulgadas
plt.figure(figsize=(10, 7))

# Definimos un color celeste agradable para las barras
color_celeste = "#386FC7"

# Creamos las barras del gráfico
# Eje X → nombre de producto
# Eje Y → ingreso total
# color=color_celeste aplica el color definido arriba
barras = plt.bar(df_ordenado["producto"], df_ordenado["ingreso_total"], color='#1E1AA1')

# Agregamos un título al gráfico con tamaño de fuente 14 y en negrita
plt.title("Ingresos Totales por Producto", fontsize=14, weight="bold")

# Etiquetamos los ejes
plt.xlabel("Producto", fontsize=12)        # Eje X
plt.ylabel("Ingreso Total ($)", fontsize=12)  # Eje Y

# Rotamos las etiquetas del eje X para que los nombres de los productos se lean bien
plt.xticks(rotation=90)

# Recorremos cada barra dibujada para agregar el valor de ingreso dentro de ella
for barra in barras:
    # Obtenemos la altura de la barra (equivale al valor de ingreso_total)
    y = barra.get_height()

    # Escribimos el texto dentro de la barra
    plt.text(
        barra.get_x() + barra.get_width() / 2,  # posición horizontal: centro de la barra
        y / 2,                                  # posición vertical: mitad de la barra
        f"${y:,.0f}",                           # texto formateado con separador de miles
        ha='center',                            # alineación horizontal centrada
        va='center',                            # alineación vertical centrada
        fontsize=9,                             # tamaño de fuente pequeño
        color="white",                          # texto blanco para contrastar con el celeste
        rotation=90                             # rotamos el texto 90° para que quede vertical
    )

# Ajustamos automáticamente los márgenes del gráfico para que no se corte nada
plt.tight_layout()

# Mostramos el gráfico final
plt.show()

# %%
df.describe()
# Out:
#        ingreso_total    unidades  precio_promedio  registros
# count           30.0        30.0        30.000000       30.0
# mean    48903.117333  649.833333        75.179333  99.933333
# std     13265.561715  169.020522         2.317448  25.858945
# min          11128.8       160.0        71.380000       24.0
# 25%         45601.92      623.75        73.692500      100.0
# 50%        48140.245       635.5        74.750000      100.0
# 75%         51092.96       672.0        76.250000      100.0
# max         82276.38      1112.0        81.400000      176.0

# %%
media = df['ingreso_total'].mean()
mediana = df['ingreso_total'].median()
moda = df['ingreso_total'].mode()

print("Media:", media)
print("Mediana:", mediana)
print("Moda:")
print(moda)
# Out:
# Media: 48903.117333333335
# Mediana: 48140.244999999995
# Moda:
# 0      11128.8
# 1      25736.8
# 2     25856.57
# 3     44773.06
# 4     44865.03
# 5     45196.63
# 6     45217.96
# 7     45411.09
# 8     46174.41
# 9     46179.48
# 10    46783.31
# 11    47038.04
# 12    47779.46
# 13    47836.86
# 14    48093.49
# 15     48187.0
# 16    48946.44
# 17     49913.9
# 18    50085.86
# 19    50155.15
# 20    50456.45
# 21     50979.2
# 22    51130.88
# 23    52115.45
# 24    54132.44
# 25     54297.6
# 26    59607.31
# 27    72562.89
# 28    74175.58
# 29    82276.38
# Name: ingreso_total, dtype: Float64

# %%
rango = df['ingreso_total'].max() - df['ingreso_total'].min()
varianza = df['ingreso_total'].var(ddof=1)
desviacion = df['ingreso_total'].std(ddof=1)

#TAREA
#CALCULAR LA DESVIACION ESTANDAR Y EL RANGO DE CANTIDADES Y PRECIO_PROMEDIO DEL MISMO DATASET RESUMEN_PROD = DF

print("Rango:", rango)
print("Varianza:", varianza)
print("Desviación estándar:", desviacion)
# Out:
# Rango: 71147.58
# Varianza: 175975127.6254547
# Desviación estándar: 13265.561715413889

# %%
print(f"Media de Ingreso Total: {media:,.2f}")
print(f"Mediana de Ingreso Total: {mediana:,.2f}")
print(f"Desviación Estándar de Ingreso Total: {desviacion:,.2f}")
print(f"Rango de Ingreso Total: {rango:,.2f}")
# Out:
# Media de Ingreso Total: 48,903.12
# Mediana de Ingreso Total: 48,140.24
# Desviación Estándar de Ingreso Total: 13,265.56
# Rango de Ingreso Total: 71,147.58

# %%
q1 = df['ingreso_total'].quantile(0.25)
q2 = df['ingreso_total'].quantile(0.5)
q3 = df['ingreso_total'].quantile(0.75)
iqr = q3 - q1

print("Q1:", q1)
print("Mediana (Q2):", q2)
print("Q3:", q3)
print("IQR:", iqr)

lim_inf = q1 - 1.5 * iqr
lim_sup = q3 + 1.5 * iqr

outliers = df[(df['ingreso_total'] < lim_inf) | (df['ingreso_total'] > lim_sup)]

print("Límite inferior:", lim_inf)
print("Límite superior:", lim_sup)
print("\nOutliers detectados:")
print(outliers)
# Out:
# Q1: 45601.92
# Mediana (Q2): 48140.244999999995
# Q3: 51092.96
# IQR: 5491.040000000001
# Límite inferior: 37365.36
# Límite superior: 59329.520000000004
#
# Outliers detectados:
#            producto  ingreso_total  unidades  precio_promedio  registros  \
# 3       Auriculares       74175.58       958            76.30        143
# 5          Cafetera       59607.31       765            79.05        117
# 6        Candelabro        11128.8       160            74.60         24
# 14         Heladera        25736.8       330            74.13         48
# 19  Lámpara De Mesa       82276.38      1112            72.72        176
# 20       Microondas       72562.89       912            79.18        135
# 28           Tablet       25856.57       374            71.38         58
#
#             categoria
# 3         Electrónica
# 5   Electrodomésticos
# 6          Decoración
# 14  Electrodomésticos
# 19         Decoración
# 20  Electrodomésticos
# 28        Electrónica

# %% [markdown]
# Ingresos totales por Categoría

# %%
ventas_x_categ = ventas_perf.copy().groupby(by='categoria').agg(
        ingreso_total=('ingreso', 'sum'),   # Suma de 'ingreso' por grupo.
        unidades=('cantidad', 'sum'),       # Suma de 'cantidad' por grupo.
        precio_promedio=('precio', 'mean'), # Promedio simple de 'precio' por grupo.
        registros=('ingreso', 'size'),      # Número de filas en el grupo.
    ).reset_index()

display(ventas_x_categ.head(5))
# Out:
#            categoria  ingreso_total  unidades  precio_promedio  registros
# 0         Decoración      479216.09      6490         74.09800       1000
# 1  Electrodomésticos      505299.63      6592         76.52096       1000
# 2        Electrónica       482577.8      6413         75.25492        998

# %%
# =========================================
# 📊 Gráfico de barras con etiquetas verticales dentro de cada barra
# =========================================

# Importamos la librería de gráficos matplotlib
import matplotlib.pyplot as plt

# Ordenamos el DataFrame por la columna "ingreso_total" de mayor a menor
# Esto permite que las barras se muestren ordenadas por el monto de ventas
ventas_x_categ = ventas_x_categ.sort_values("ingreso_total", ascending=False)

# Creamos la figura donde se va a dibujar el gráfico
# figsize define el tamaño del gráfico (ancho, alto) en pulgadas
plt.figure(figsize=(5,5))

display(ventas_x_categ.head(5))

# Creamos las barras del gráfico
barras2 = plt.bar(ventas_x_categ["categoria"], ventas_x_categ["ingreso_total"], color='#1BBBB1')

# Agregamos un título al gráfico con tamaño de fuente 14 y en negrita
plt.title("Ingresos Totales por Categoría", fontsize=14, weight="bold")

# Etiquetamos los ejes
plt.xlabel("Categoría", fontsize=12, weight="bold")          # Eje X
plt.ylabel("Ingreso Total ($)", fontsize=12, weight="bold")  # Eje Y

# Recorremos cada barra dibujada para agregar el valor de ingreso dentro de ella
for x in barras2:
    # Obtenemos la altura de la barra (equivale al valor de ingreso_total)
    y = x.get_height()

    # Escribimos el texto dentro de la barra
    plt.text(
        x.get_x() + x.get_width() / 2,  # posición horizontal: centro de la barra
        y / 2,                                  # posición vertical: mitad de la barra
        f"${y:,.0f}",                           # texto formateado con separador de miles
        ha='center',                            # alineación horizontal centrada
        va='center',                            # alineación vertical centrada
        fontsize=12,                             # tamaño de fuente pequeño
        color="white",                          # texto blanco para contrastar con el celeste
        rotation=90                             # rotamos el texto 90° para que quede vertical
    )

# Ajustamos automáticamente los márgenes del gráfico para que no se corte nada
plt.tight_layout()

# Mostramos el gráfico final
plt.show()
# Out:
#            categoria  ingreso_total  unidades  precio_promedio  registros
# 1  Electrodomésticos      505299.63      6592         76.52096       1000
# 2        Electrónica       482577.8      6413         75.25492        998
# 0         Decoración      479216.09      6490         74.09800       1000

# %%
ventas_x_categ.describe()
# Out:
#        ingreso_total     unidades  precio_promedio   registros
# count            3.0          3.0         3.000000         3.0
# mean   489031.173333  6498.333333        75.291293  999.333333
# std     14188.808451    89.790497         1.211889    1.154701
# min        479216.09       6413.0        74.098000       998.0
# 25%       480896.945       6451.5        74.676460       999.0
# 50%         482577.8       6490.0        75.254920      1000.0
# 75%       493938.715       6541.0        75.887940      1000.0
# max        505299.63       6592.0        76.520960      1000.0

# %% [markdown]
# ###2- Análisis Exploratorio de Datos (EDA): Realizar un análisis exploratorio utilizando visualizaciones para identificar patrones y tendencias en las ventas.

# %%
# Boxplot: dispersión de ingreso_total (por producto)

import matplotlib.pyplot as plt  # importamos matplotlib

df_eda = df_ordenado['ingreso_total'].dropna()

plt.figure(figsize=(5, 5))
plt.boxplot(df_eda, vert=True)
plt.title('Dispersión de ingreso_total (por producto)')
plt.ylabel('Ingreso total ($)')
plt.tight_layout()
plt.show()

# %%
# Histograma para ver la distribución

import matplotlib.pyplot as plt  # importamos matplotlib

plt.figure(figsize=(10, 5))
sns.histplot(df_eda, kde=True, color='#1E1AA1')
plt.title('Distribución del Ingreso total por producto')
plt.xlabel('Ingreso Total')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ###3- Correlación: Evaluar la relación entre diferentes variables (por ejemplo, precio y cantidad vendida) y mostrar los resultados en un gráfico.

# %%
# Dispersión: precio_promedio vs unidades (por producto)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.scatter(df_ordenado['precio_promedio'] , df_ordenado['unidades'], color='#1E1AA1' )
plt.title('Precio promedio vs Unidades (por producto)')
plt.xlabel('Precio promedio')
plt.ylabel('Unidades vendidas')
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluamos la relación entre precio_promedio y unidades por producto. Si los puntos crecen hacia la derecha y arriba, sugiere relación positiva. También mostramos el coeficiente de correlación.

# %%
# Coeficiente de correlación (precio_promedio vs unidades)

corr_val = df_ordenado[['precio_promedio','unidades']].corr().loc['precio_promedio','unidades']

print(f"Coeficiente de Correlación (Pearson): {corr_val:.3f}")
# Interpretación simple:
if corr_val > 0.8:
    print("Interpretación: Correlación positiva clara (a mayor precio_promedio, suelen venderse más unidades).")
elif corr_val > 0.2:
    print("Interpretación: Correlación positiva débil a moderada.")
elif corr_val < -0.8:
    print("Interpretación: Correlación negativa clara (a mayor precio_promedio, suelen venderse menos unidades).")
elif corr_val < -0.3:
    print("Interpretación: Correlación negativa débil a moderada.")
else:
    print("Interpretación: relación muy débil o nula.")
# Out:
# Coeficiente de Correlación (Pearson): 0.217
# Interpretación: Correlación positiva débil a moderada.

# %% [markdown]
# ###4- Consolidación de Datos: Consolidar todos los análisis previos y preparar un conjunto de datos final que resuma los hallazgos clave para la presentación.

# %% [markdown]
# BARRAS - INGRESOS TOTALES POR PRODUCTO

# %%
import matplotlib.pyplot as plt  # importamos la librería de gráficos

df = resumen_prod.copy()                                # copiamos para no modificar el original
df_ordenado = df.sort_values('ingreso_total', ascending=False)  # ordenamos desc por ingreso

plt.figure(figsize=(12, 6))                             # tamaño del gráfico
barras = plt.bar(df_ordenado['producto'], df_ordenado['ingreso_total'], color='#1BBBB1')  # dibujamos las barras

plt.title('Ingresos Totales por Producto')              # título del gráfico
plt.xlabel('Producto')                                  # etiqueta eje X
plt.ylabel('Ingreso Total ($)')                         # etiqueta eje Y
plt.xticks(rotation=90)                                  # rotamos etiquetas del eje X para legibilidad

# Etiquetamos el valor dentro de cada barra (texto vertical)
for b in barras:
    h = b.get_height()                                  # altura de la barra (valor)
    x_c = b.get_x() + b.get_width()/2                   # centro horizontal de la barra
    plt.text(x_c, h/2, f"${h:,.0f}", ha='center', va='center', rotation=90)  # texto dentro, vertical

plt.tight_layout()                                      # ajustar márgenes
plt.show()                                              # mostrar gráfico

# %% [markdown]
# LINEAS - Ingreso acumulado a lo largo del tiempo

# %%
# Usamos el dataset 'ventas_perf', que contiene la fecha y el ingreso de cada registro.

import matplotlib.pyplot as plt

# Convertimos la columna 'fecha_venta' a tipo datetime (por seguridad)
ventas_perf['fecha_venta'] = pd.to_datetime(ventas_perf['fecha_venta'], errors='coerce')

# Creamos una columna para el mes y año
ventas_perf['año_mes'] = ventas_perf['fecha_venta'].dt.to_period('M')

# Agrupamos las ventas por mes y sumamos los ingresos de cada mes
ingresos_por_mes = ventas_perf.groupby('año_mes')['ingreso'].sum().sort_index()

# Calculamos el acumulado de ingresos mensuales
ingresos_acumulados_mes = ingresos_por_mes.cumsum()

# Graficamos ambas curvas: ingresos mensuales y acumulados
plt.figure(figsize=(12,6))

# Línea 1: ingresos mensuales
plt.plot(ingresos_por_mes.index.astype(str), ingresos_por_mes, color='#1BBBB1', label='Ingreso mensual')

# Línea 2: ingresos acumulados mensuales
plt.plot(ingresos_acumulados_mes.index.astype(str), ingresos_acumulados_mes, color='#111BB1', label='Ingreso acumulado', linewidth=2)

# Personalización del gráfico
plt.title('Evolución de ingresos por mes de venta')
plt.xlabel('Mes de venta')
plt.ylabel('Ingresos ($)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45) # Rota etiquetas del eje x para que se vea mejor el mes
plt.tight_layout()
plt.show()

# %% [markdown]
# TORTA - Distribución del Ingreso según Categorías

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Agrupar por categoría y sumar el ingreso total
ingreso_por_categoria = ventas_perf.groupby('categoria')['ingreso'].sum().sort_values(ascending=False)

# Definir una paleta de colores de Seaborn
colors = sns.color_palette('viridis')[0:len(ingreso_por_categoria)] # Puedes cambiar 'pastel' por otras paletas como 'viridis', 'magma', 'coolwarm', etc.

# Crear el gráfico de torta
plt.figure(figsize=(5, 5))
wedges, texts, autotexts = plt.pie(
    ingreso_por_categoria,
    labels=ingreso_por_categoria.index,
    autopct='%1.1f%%',
    startangle=90,
    wedgeprops={'edgecolor': 'black'},
    colors=colors
)

# Aplicar formato blanco y negrita a los porcentajes
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_weight('bold')
    autotext.set_size(12)

plt.title('Distribución del Ingreso Total por Categoría', fontsize=16)
plt.axis('equal') # Asegura que el gráfico de torta sea circular.
plt.show()

# %% [markdown]
# BOXPLOT - Cantidad de unidades vendidas por venta, diferenciadas por categoría

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear el diagrama de caja
plt.figure(figsize=(10, 6))
sns.boxplot(x='categoria', y='cantidad', data=ventas_perf, color='#1EEEE1')

# Personalizar el gráfico
plt.title('Cantidad de Unidades Vendidas por Transacción y Categoría', fontsize=16)
plt.xlabel('Categoría de Producto', fontsize=12)
plt.ylabel('Cantidad de Unidades Vendidas por Transacción', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# MAPA DE CALOR - Unidades Vendidas e Ingreso Total

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccionar las columnas de interés
correlation_data = df[['unidades', 'ingreso_total']]

# Calcular la matriz de correlación
correlation_matrix = correlation_data.corr()

# Crear el mapa de calor
plt.figure(figsize=(6, 5))
sns.heatmap(
    correlation_matrix,
    annot=True,    # Mostrar los valores de correlación en el mapa
    cmap='coolwarm', # Elegir un mapa de color
    fmt=".2f",     # Formato de los números en las anotaciones
    linewidths=.5  # Líneas entre las celdas
)
plt.title('Mapa de Calor de Correlación: Unidades Vendidas vs Ingreso Total', fontsize=14)
plt.show()

# %% [markdown]
# MAPA DE CALOR - Costo e Ingreso Total (Marketing vs. Ingresos)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccionar las columnas de interés del merged_df
correlation_data_merged = merged_df[['costo', 'precio_por_cantidad']]

# Calcular la matriz de correlación
correlation_matrix_merged = correlation_data_merged.corr()

# Crear el mapa de calor
plt.figure(figsize=(6, 5))
sns.heatmap(
    correlation_matrix_merged,
    annot=True,    # Mostrar los valores de correlación en el mapa
    cmap='coolwarm', # Elegir un mapa de color
    fmt=".2f",     # Formato de los números en las anotaciones
    linewidths=.5  # Líneas entre las celdas
)
plt.title('Mapa de Calor de Correlación: Costo vs Precio por Cantidad', fontsize=14)
plt.show()

# %% [markdown]
# HISTOGRAMA - Distribución de ingreso_total (por producto)

# %%
# reseteo los valores por defecto de plt y sns
plt.rcdefaults()
sns.set()

serie = resumen_prod['ingreso_total']        # elegimos la serie numérica a analizar

plt.figure(figsize=(8, 5))                   # definimos tamaño del gráfico
plt.hist(serie, bins=12, color='#1BBBB1')    # dibujamos histograma con 12 intervalos
plt.title('Distribución de ingreso_total (por producto)')  # título del gráfico
plt.xlabel('Ingreso total ($)')              # etiqueta del eje X
plt.ylabel('Frecuencia')                     # etiqueta del eje Y
plt.tight_layout()                           # ajustamos márgenes para que no se corte el contenido
plt.show()                                   # mostramos el gráfico

# %% [markdown]
# # Presentación Final — Conclusiones Integrales del Proyecto

# %% [markdown]
# ##Conclusiones Finales del Proyecto
# A lo largo del proyecto se llevó adelante un proceso completo de análisis de datos, desde la recopilación y limpieza hasta la integración y exploración analítica. La depuración de los tres datasets permitió estandarizar formatos, corregir inconsistencias y eliminar duplicados, garantizando una base sólida para el análisis posterior.
#
# El estudio de ventas reveló que los productos de mayor desempeño pertenecen principalmente a las categorías de **Electrodomésticos y Electrónica**, destacándose especialmente Lámpara de Mesa, Auriculares y Microondas como los de mayor ingreso total. El análisis por percentiles permitió identificar el top 20% de productos de alto rendimiento, lo que ofrece una referencia clara para priorizar inventario, marketing y estrategias comerciales.
#
# A nivel agregado, las tres categorías presentan ingresos totales similares, aunque **Electrodomésticos** muestra un rendimiento ligeramente superior. La integración con los datos de campañas permitió analizar la relación entre ingresos y costos de marketing, evidenciando que el gasto representa un porcentaje muy bajo del ingreso generado (entre 0,02% y 0,13%), lo que sugiere campañas altamente eficientes.
#
# Finalmente, el análisis estadístico y las visualizaciones facilitaron la identificación de patrones de comportamiento y outliers relevantes, aportando una visión completa sobre tendencias, dispersión e impacto por producto y categoría. Este conjunto de insights constituye una base sólida para futuras decisiones estratégicas orientadas a optimizar ventas, inversión publicitaria y gestión de productos.

# %% [markdown]
# ##Storytelling del Proyecto – Análisis de Datos para SynthData
#
# ###1. El punto de partida
# El proyecto comenzó con tres datasets independientes —ventas, clientes y marketing— que representaban distintas áreas del negocio. Cada uno contenía información valiosa, pero también inconsistencias, duplicados y formatos heterogéneos que dificultaban cualquier análisis.
# La misión inicial fue clara: convertir datos dispersos en una base confiable, lista para responder preguntas estratégicas del negocio.
#
# ###2. Preparando el terreno: limpieza y estandarización de datos
# El primer paso fue la detección y corrección de problemas de calidad:
# * Se identificaron nulos, inconsistencias en texto, fechas y valores numéricos.
# * Se eliminaron duplicados —en ventas, algunos IDs estaban repetidos hasta dos veces—.
# * Se estandarizaron formatos de fechas, textos y precios.
# * Finalmente, todos los valores inválidos fueron tratados o eliminados según correspondía.
#
# Este proceso permitió obtener datos limpios, coherentes y listos para análisis.
#
# ###3. Transformación: de registros aislados a métricas accionables
# Con los datos ya limpios, el foco pasó a una transformación clave: **medir el desempeño real de los productos.**
# Para eso se creó la métrica ingreso por registro (precio × cantidad) y luego se agregaron métricas por producto:
# * ingreso total
# * unidades vendidas
# * precio promedio
# * registros totales
#
# Este paso permitió identificar tendencias invisibles en el dataset bruto.
#
# ###4. Insights que importan: **¿qué productos impulsan el negocio?**
# Para entender el rendimiento del portafolio, se aplicó un enfoque basado en percentiles. El análisis del P80 determinó cuáles eran los productos de alto rendimiento, es decir, el top 20% del catálogo.
# Los grandes ganadores fueron:
# * Lámpara de Mesa
# * Auriculares
# * Microondas
#
# Estos productos se destacan por su volumen, su precio y su impacto en el ingreso total.
#
# ###5. Mirada por categorías: equilibrio y oportunidades
# Al agrupar el ingreso por categorías (Decoración, Electrodomésticos y Electrónica), surgió un dato interesante: las tres categorías muestran niveles de ingresos muy similares.
# Sin embargo, Electrodomésticos aparece levemente por encima, lo cual la posiciona como una categoría estratégica para potenciar.
# Además, se calculó el ticket promedio, que se mantiene estable en todas las categorías, mostrando un comportamiento homogéneo del mercado.
#
# ###6. Integración con marketing: ¿es rentable la inversión?
# Uno de los puntos más valiosos del proyecto fue la integración entre ventas y campañas de marketing.
# Al unir ambos datasets por producto, se evaluó la relación entre ingresos y costos publicitarios.
#
# **Resultado clave: El costo de marketing representa entre 0,02% y 0,13% del ingreso total por producto.**
# Esto muestra campañas extremadamente eficientes, con un costo ínfimo en relación al retorno.
#
# ###7. Análisis estadístico y EDA: profundidad y validación.
# Para validar tendencias y detectar anomalías se aplicaron:
# * medidas de tendencia central y dispersión,
# * gráficos boxplots e histogramas,
# * análisis de outliers,
# * análisis por percentiles.
# Este enfoque permitió confirmar que:
# * El comportamiento de los productos es consistente.
# * Existen outliers tanto por muy alto rendimiento (Auriculares, Lámpara de Mesa) como por bajo volumen (Candelabro, Heladera).
# * La dispersión es adecuada y no afecta la representatividad del análisis.
#
# ###8. El cierre: datos que guían decisiones reales.
# El proyecto permitió transformar datos desordenados en insights accionables, entre ellos:
# * Identificar los productos estrella del negocio.
# * Detectar oportunidades de optimización por categoría.
# * Comprender el impacto real de las campañas de marketing.
# * Mejorar la capacidad de priorizar inventario, promociones y estrategias comerciales.
#
# El análisis dejó una base sólida para decisiones basadas en datos y para la construcción de dashboards operativos o reportes ejecutivos.
